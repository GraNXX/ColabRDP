# %% [markdown]
# <a href="https://colab.research.google.com/github/GraNXX/ColabRDP/blob/main/GranGuorgeRDP_25GB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **WELCOME TO GranGuorgeMC**
# Rdp vps notebook
#
# This is a free rdp
# Free for all users
#
# Its active **6hours to 1 month max**
# In chrome
#
# **25GB OF RAM**
#
# Enjoy the rdp
# Before *****it lost***** soon.
#
# * *first* - you need to to download all codes if fill blank [(download here)](https://download1491.mediafire.com/50bn9oufvl0g/ndzw3sotncf0wch/HOW+TO+MAKE+VPS+24.7.zip)
#
# * copy you debain CRP in [headless](http://remotedesktop.google.com/headless)<br><br>
#
# *  *second* - tap the play button or run  and wait in 4 to 5 min to setup
#
# * *third* - if you wand to muont your google drive account. run the 2nd part
#
# * open [chrome remote destop](https://remotedesktop.google.com/)
# <br><br>

# %%
 
#@title **Create VPS-RDP**
#@markdown Enter Username and Password
 
import os 
 
 
username = "GranMC" #@param {type:"string"}
password = "root" #@param {type:"string"}
 
print(f"Creating '{username}' user")
 
# Creation of user
os.system(f"useradd -m {username}")
 
# Add user to sudo group
os.system(f"adduser {username} sudo")
    
# Set password of user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")
 
# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")
 
print(f"'{username}' created")
 
#@title **Rdp**
#@markdown  It takes 4-5 minutes for installation
 
import os
import subprocess
 
#@markdown  Visit [remote headless](http://remotedesktop.google.com/headless) and Copy the command after authentication
 
CRP = "DISPLAY= /opt/google/chrome-remote-desktop/start-host --code=\"4/0AX4XfWh16xQU2QP4hu3lkjgZhkQ3XpPDyYm3QY9JYafxhavHe_soOLH4UepNR3ZpNXkKmQ\" --redirect-url=\"https://remotedesktop.google.com/_/oauthredirect\" --name=$(hostname)" #@param {type:"string"}
 
#@markdown Enter a pin more or equal to 6 digits
Pin =  200020#@param {type: "integer"}
 
#@markdown **Select browser** that you want to install. YOU CAN SELECT ALL
GoogleChrome = True #@param {type:'boolean'}
Onion = False #@param {type:'boolean'}
FireFox = False #@param {type:'boolean'}
Brave = True #@param {type:'boolean'}

 
        
 
class CRD:
    def __init__(self):
        os.system("apt update")
        self.installCRD()
        self.installDesktopEnvironment()
        self.runOS()
        self.installAPPS()
        self.finish()
 
    @staticmethod
    def installCRD():
        print("Installing Chrome Remote Desktop")
        subprocess.run(['wget', 'https://dl.google.com/linux/direct/chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['dpkg', '--install', 'chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)
 
    @staticmethod
    def installDesktopEnvironment():
        print("Installing Desktop Environment")
        os.system("export DEBIAN_FRONTEND=noninteractive")
        os.system("apt install --assume-yes xfce4 desktop-base xfce4-terminal")
        os.system("bash -c 'echo \"exec /etc/X11/Xsession /usr/bin/xfce4-session\" > /etc/chrome-remote-desktop-session'")
        os.system("apt remove --assume-yes gnome-terminal")
        os.system("apt install --assume-yes xscreensaver")
        os.system("systemctl disable lightdm.service")
    
    @staticmethod
    def runOS():
        if GoogleChrome:
            print("installing GoogleChrome")
            subprocess.run(["wget", "https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
            subprocess.run(["dpkg", "--install", "google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
            subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)
        if Onion:
            print("installing Onion browser")
            os.system("add-apt-repository ppa:micahflee/ppa")
            os.system("apt update")
            os.system("apt install torbrowser-launcher")
            print("be careful to use onion browser dont full screen the app beacouse you real ip will be know to the hacker and you all data will be gone")
        if FireFox:
            print("installing Firefox browser")
            os.system("apt install firefox")
        if Brave:
            print("installing Brave Broser")
            os.system("wget https://raw.githubusercontent.com/GranGuorgeMC/DOWNLOADS-FILES/main/brave%2Cbrowser.GranMC")
            os.system("chmod +x brave,browser.GranMC")
            os.system("./brave,browser.GranMC")

    @staticmethod
    def installAPPS():
        print("Installing obs studio ")
        subprocess.run(['apt', 'install', 'ffmpeg'], stdout=subprocess.PIPE)
        subprocess.run(['apt',  'update'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', 'v4l2loopback-dkms'], stdout=subprocess.PIPE)
        subprocess.run(['add-apt-repository', 'ppa:obsproject/obs-studio'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'update'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', 'obs-studio'], stdout=subprocess.PIPE)
        subprocess.run(['wget', 'https://github.com/Grannnnnnnnx/RESPI/releases/download/1.10/images.jpeg'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', 'ufw'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', 'snapd'], stdout=subprocess.PIPE)
        print("installing vlc")
        subprocess.run(['apt', 'install', 'vlc'], stdout=subprocess.PIPE)
        subprocess.run(['dd', 'if=/dev/zero', 'of=/mnt/swap.0' 'bs=5024', 'count=1048576'], stdout=subprocess.PIPE)
        subprocess.run(['mkswap', '/mnt/swap.0'], stdout=subprocess.PIPE)
        subprocess.run(['su'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'update'], stdout=subprocess.PIPE)
        subprocess.run(['echo', '"/mnt/swap.0', 'swap', 'swap', 'defaults', '0', '0"', '>>', '/etc/fstab'], stdout=subprocess.PIPE)
        subprocess.run(['swapon', '/mnt/swap.0'], stdout=subprocess.PIPE)
        subprocess.run(['swapon', '-s'], stdout=subprocess.PIPE)
        
 
    @staticmethod
    def finish():
        print("Finalizing")
        os.system(f"adduser {username} chrome-remote-desktop")
        command = f"{CRP} --pin={Pin}"
        os.system(f"su - {username} -c '{command}'")
        os.system("service chrome-remote-desktop start")
        print("done")
        
 
try:
    if username:
        if CRP == "":
            print("Please enter authcode from the given link")
        elif len(str(Pin)) < 6:
            print("Enter a pin more or equal to 6 digits")
        else:
            CRD()
except NameError as e:
    print("EROR")
    print("REPORT THIS IN GITHUB")
# Out:
# Creating 'GranMC' user
# 'GranMC' created
# Installing Chrome Remote Desktop
# Installing Desktop Environment
# installing GoogleChrome
# installing Brave Broser
# Installing obs studio
# installing vlc
# Finalizing
# done

# %%
#@title **Google Drive Mount**
#@markdown Google Drive used as Persistance HDD for files.<br>
#@markdown Mounted at `user` Home directory inside drive folder
#@markdown (If `username` variable not defined then use root as default).

def MountGDrive():
    from google.colab import drive

    ! runuser -l $user -c "yes | python3 -m pip install --user google-colab"  > /dev/null 2>&1

    mount = """from os import environ as env
from google.colab import drive

env['CLOUDSDK_CONFIG']  = '/content/.config'
drive.mount('{}')""".format(mountpoint)

    with open('/content/mount.py', 'w') as script:
        script.write(mount)

    ! runuser -l $user -c "python3 /content/mount.py"

try:
    if username:
        mountpoint = "/home/"+username+"/drive"
        user = username
except NameError:
    print("username variable not found, mounting at `/content/drive' using `root'")
    mountpoint = '/content/drive'
    user = 'root'

MountGDrive()

# %%
#@title **SSH**

! pip install colab_ssh --upgrade &> /dev/null

Ngrok = False #@param {type:'boolean'}

#@markdown Copy authtoken from https://dashboard.ngrok.com/auth (only for ngrok)
ngrokToken = "" #@param {type:'string'}


def runNGROK():
    from colab_ssh import launch_ssh
    from IPython.display import clear_output
    launch_ssh(ngrokToken, password)
    clear_output()

    print("ssh", username, end='@')
    ! curl -s http://localhost:4040/api/tunnels | python3 -c \
            "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"



try:
    if username:
        if ngrokToken == "":
            print("Please enter authcode from the given link")
        elif len(str(Pin)) < 6:
            print("Enter a pin more or equal to 6 digits")
        else:
            CRD()
except NameError as e:
    print("username variable not found")
    print("Create a User First")

# %%
#@title **install application**

apt = "" #@param {type:'boolean'}
dpkg = False #@param {type:'boolean'}
custom = "" #@param {type:'boolean'}

apt = "" #@param {type:"string"}
dpkg = False #@param {type:"string"}
custom = "" #@param {type:"string"}

if apt: 
  ! apt install {apt}

if  dpkg:
  ! dpkg --install {dpkg}

if custom:
  ! {custom}

# %% [markdown]
# # **Prevent from disconnecting**
# # **Press F12 then enter this code:**
# ```
# function ClickConnect() {
#   console.log('Working')
#   document
#     .querySelector('#top-toolbar > colab-connect-button')
#     .shadowRoot.querySelector('#connect')
#     .click()
# }
#
# setInterval(ClickConnect, 60000)
